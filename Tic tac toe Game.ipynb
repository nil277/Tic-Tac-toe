# %%
#Importing the libraries

from tkinter import *
from tkinter import messagebox
from random import choice

# %%
#create a window
root = Tk()


#create global variable
count = 0
clicked = False
one_player = True


#create robot Function
def robot():
	global selected_list
	
	#ATACING
	#ROW1
	if b1["text"]=='O' and b2["text"]=='O'and b3["text"] == "	":
		b3["text"]= 'O'
		selected_list.append(b3)
	
	elif b1["text"]=='O' and b2["text"]=='	'and b3["text"] == "O":
		b2["text"]= 'O'
		selected_list.append(b2)
		
	elif b1["text"]=='	' and b2["text"]=='O'and b3["text"] == "O":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#ROW2
	elif b4["text"]=='O' and b5["text"]=='O'and b6["text"] == "	":
		b6["text"]= 'O'
		selected_list.append(b6)
	
	elif b4["text"]=='O' and b5["text"]=='	'and b6["text"] == "O":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b4["text"]=='	' and b5["text"]=='O'and b6["text"] == "O":
		b4["text"]= 'O'
		selected_list.append(b4)
	
	#ROW 3
	elif b7["text"]=='O' and b8["text"]=='O'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b7["text"]=='O' and b8["text"]=='	'and b9["text"] == "O":
		b8["text"]= 'O'
		selected_list.append(b8)
	
	elif b7["text"]=='	' and b8["text"]=='O'and b9["text"] == "O":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	#COLUMN 1
	elif b1["text"]=='O' and b4["text"]=='O'and b7["text"] == "	":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	elif b1["text"]=='O' and b4["text"]=='	'and b7["text"] == "O":
		b4["text"]= 'O'
		selected_list.append(b4)
	
	elif b1["text"]=='	' and b4["text"]=='O'and b7["text"] == "O":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#COLUMN 2
	elif b2["text"]=='O' and b5["text"]=='O'and b8["text"] == "	":
		b8["text"]= 'O'
		selected_list.append(b8)
	
	elif b2["text"]=='O' and b5["text"]=='	'and b8["text"] == "O":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b2["text"]=='	' and b5["text"]=='O'and b8["text"] == "O":
		b2["text"]= 'O'
		selected_list.append(b2)
	
	#Column 3
	elif b3["text"]=='O' and b6["text"]=='O'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b3["text"]=='O' and b6["text"]=='	'and b9["text"] == "O":
		b6["text"]= 'O'
		selected_list.append(b6)
	
	elif b3["text"]=='	' and b6["text"]=='O'and b9["text"] == "O":
		b3["text"]= 'O'
		selected_list.append(b3)
	
	#CROSS 1
	elif b1["text"]=='O' and b5["text"]=='O'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b1["text"]=='O' and b5["text"]=='	'and b9["text"] == "O":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b1["text"]=='	' and b5["text"]=='O'and b9["text"] == "O":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#CROSS 2
	elif b3["text"]=='O' and b5["text"]=='O'and b7["text"] == "	":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	elif b3["text"]=='O' and b5["text"]=='	'and b7["text"] == "O":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b3["text"]=='	' and b5["text"]=='O'and b7["text"] == "O":
		b3["text"]= 'O'
		selected_list.append(b3)
		
	
	
	#DEFENCE
	#ROW1
	elif b1["text"]=='X' and b2["text"]=='X'and b3["text"] == "	":
		b3["text"]= 'O'
		selected_list.append(b3)
	
	elif b1["text"]=='X' and b2["text"]=='	'and b3["text"] == "X":
		b2["text"]= 'O'
		selected_list.append(b2)
		
	elif b1["text"]=='	' and b2["text"]=='X'and b3["text"] == "X":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#ROW2
	elif b4["text"]=='X' and b5["text"]=='X'and b6["text"] == "	":
		b6["text"]= 'O'
		selected_list.append(b6)
	
	elif b4["text"]=='X' and b5["text"]=='	'and b6["text"] == "X":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b4["text"]=='	' and b5["text"]=='X'and b6["text"] == "X":
		b4["text"]= 'O'
		selected_list.append(b4)
	
	#ROW 3
	elif b7["text"]=='X' and b8["text"]=='X'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b7["text"]=='X' and b8["text"]=='	'and b9["text"] == "X":
		b8["text"]= 'O'
		selected_list.append(b8)
	
	elif b7["text"]=='	' and b8["text"]=='X'and b9["text"] == "X":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	#COLUMN 1
	elif b1["text"]=='X' and b4["text"]=='X'and b7["text"] == "	":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	elif b1["text"]=='X' and b4["text"]=='	'and b7["text"] == "X":
		b4["text"]= 'O'
		selected_list.append(b4)
	
	elif b1["text"]=='	' and b4["text"]=='X'and b7["text"] == "X":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#COLUMN 2
	elif b2["text"]=='X' and b5["text"]=='X'and b8["text"] == "	":
		b8["text"]= 'O'
		selected_list.append(b8)
	
	elif b2["text"]=='X' and b5["text"]=='	'and b8["text"] == "X":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b2["text"]=='	' and b5["text"]=='X'and b8["text"] == "X":
		b2["text"]= 'O'
		selected_list.append(b2)
	
	#Column 3
	elif b3["text"]=='X' and b6["text"]=='X'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b3["text"]=='X' and b6["text"]=='	'and b9["text"] == "X":
		b6["text"]= 'O'
		selected_list.append(b6)
	
	elif b3["text"]=='	' and b6["text"]=='X'and b9["text"] == "X":
		b3["text"]= 'O'
		selected_list.append(b3)
	
	#CROSS 1
	elif b1["text"]=='X' and b5["text"]=='X'and b9["text"] == "	":
		b9["text"]= 'O'
		selected_list.append(b9)
	
	elif b1["text"]=='X' and b5["text"]=='	'and b9["text"] == "X":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b1["text"]=='	' and b5["text"]=='X'and b9["text"] == "X":
		b1["text"]= 'O'
		selected_list.append(b1)
	
	#CROSS 2
	elif b3["text"]=='X' and b5["text"]=='X'and b7["text"] == "	":
		b7["text"]= 'O'
		selected_list.append(b7)
	
	elif b3["text"]=='X' and b5["text"]=='	'and b7["text"] == "X":
		b5["text"]= 'O'
		selected_list.append(b5)
	
	elif b3["text"]=='	' and b5["text"]=='X'and b7["text"] == "X":
		b3["text"]= 'O'
		selected_list.append(b3)
		
	else:
		while True:
			button_no = choice(button_list)
			if button_no not in selected_list:
				selected_list.append(button_no)
				break
		button_no["text"]='O'
		
		
	global clicked,count
	clicked = False
	count += 1


#create newgame function
def new_game():
	global count,clicked
	count = 0
	clicked = False
	reset()

#create disable_button function
def disable_button():
	b1["state"]="disable"
	b2["state"]="disable"
	b3["state"]="disable"
	b4["state"]="disable"
	b5["state"]="disable"
	b6["state"]="disable"
	b7["state"]="disable"
	b8["state"]="disable"
	b9["state"]="disable"
	

#create winner function
def winner():
	#check for X is win
	if b1["text"]=="X" and b2["text"] == "X" and b3["text"]=="X":
		b1["bg"]="red"
		b2["bg"]="red"
		b3["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
	
	elif b4["text"]=="X" and b5["text"] == "X" and b6["text"]=="X":
		b4["bg"]="red"
		b5["bg"]="red"
		b6["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
		
	elif b7["text"]=="X" and b8["text"] == "X" and b9["text"]=="X":
		b7["bg"]="red"
		b8["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
	
	elif b1["text"]=="X" and b4["text"] == "X" and b7["text"]=="X":
		b1["bg"]="red"
		b4["bg"]="red"
		b7["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
		
	elif b2["text"]=="X" and b5["text"] == "X" and b8["text"]=="X":
		b2["bg"]="red"
		b5["bg"]="red"
		b8["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
	
	elif b3["text"]=="X" and b6["text"] == "X" and b9["text"]=="X":
		b3["bg"]="red"
		b6["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
		
	elif b1["text"]=="X" and b5["text"] == "X" and b9["text"]=="X":
		b1["bg"]="red"
		b5["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
	
	elif b3["text"]=="X" and b5["text"] == "X" and b7["text"]=="X":
		b3["bg"]="red"
		b5["bg"]="red"
		b7["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! Xwin")
		return True
		
	#check for O is winner
	elif b1["text"]=="O" and b2["text"] == "O" and b3["text"]=="O":
		b1["bg"]="red"
		b2["bg"]="red"
		b3["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
	
	elif b4["text"]=="O" and b5["text"] == "O" and b6["text"]=="O":
		b4["bg"]="red"
		b5["bg"]="red"
		b6["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
		
	elif b7["text"]=="O" and b8["text"] == "O" and b9["text"]=="O":
		b7["bg"]="red"
		b8["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
	
	elif b1["text"]=="O" and b4["text"] == "O" and b7["text"]=="O":
		b1["bg"]="red"
		b4["bg"]="red"
		b7["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
		
	elif b2["text"]=="O" and b5["text"] == "O" and b8["text"]=="O":
		b2["bg"]="red"
		b5["bg"]="red"
		b8["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
	
	elif b3["text"]=="O" and b6["text"] == "O" and b9["text"]=="O":
		b3["bg"]="red"
		b6["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
		
	elif b1["text"]=="O" and b5["text"] == "O" and b9["text"]=="O":
		b1["bg"]="red"
		b5["bg"]="red"
		b9["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
	
	elif b3["text"]=="O" and b5["text"] == "O" and b7["text"]=="O":
		b3["bg"]="red"
		b5["bg"]="red"
		b7["bg"]="red"
		disable_button()
		messagebox.showinfo("winner","Congratulation! O win")
		return True
	
	else:
		if count==9:
			messagebox.showinfo("Draw","Game is draw")
			disable_button()
		


#button call function
def b_click(b):
	global clicked,count,selected_list
	
	if b["text"] == "	" and clicked == False:
		b["text"] = "X"
		clicked = True
		count += 1
		selected_list.append(b)
		if winner():
			pass
		else:
			if count < 8 and one_player:
				robot()
				winner()
	elif b["text"] == "	" and clicked == True:
		b["text"] = "O"
		clicked = False
		count += 1
		winner()
	else:
		messagebox.showerror("Tic Tac Toe","This box already have been selected")
		
def one_player():
		global one_player
		one_player = True
	
def two_player():
		global one_player
		one_player = False
		
#create a menu item
mainmenu = Menu(root)
root.config(menu = mainmenu)

optionmenu = Menu(mainmenu)
mainmenu.add_cascade(label = "File",menu = optionmenu)
optionmenu.add_command(label ="new game",command = new_game)
optionmenu.add_separator()
optionmenu.add_command(label = "one player",command = one_player)
optionmenu.add_command(label = "two player",command = two_player)





def reset():
	global b1,b2,b3,b4,b5,b6,b7,b8,b9
	global button_list,selected_list
	selected_list = []
	#define buttons
	b1 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b1)
		)
	
	b2 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b2)
		)
	
	b3 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b3)
		)
	b4 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b4)
		)
	b5 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b5)
		)
	b6 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b6)
		)
	b7 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b7)
		)
	b8 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b8)
		)
	b9 = Button(root,
		text = "	",
		font = ("Alias",15),
		width = 4,
		height = 3,
		bg = "sky blue",
		activebackground = "sky blue",
		command = lambda: b_click(b9)
		)
	
	
	button_list = [b1,b2,b3,b4,b5,b6,b7,b8,b9]
		
		
	#put all the button into the screen
	b1.grid(row = 0,column = 0)
	b2.grid(row = 0,column = 1)
	b3.grid(row = 0,column = 2)
	
	
	b4.grid(row = 1,column = 0)
	b5.grid(row = 1,column = 1)
	b6.grid(row = 1,column = 2)
	
	
	b7.grid(row = 2,column = 0)
	b8.grid(row = 2,column = 1)
	b9.grid(row = 2,column = 2)
	
reset()



root.mainloop()
